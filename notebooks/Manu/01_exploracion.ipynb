# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", None)
modify = False

# %% [markdown]
# ### Fuente de datos
#
# La información utilizada en este análisis sobre los **precios de oferta de vivienda en venta y alquiler por comunidades autónomas en España**, con series temporales a lo largo de los años, ha sido obtenida del portal de informes de precios de **idealista**:
#
# 🔗 https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/
#
# Los datos corresponden a **precios de oferta (€/m²)** publicados por idealista y se presentan desagregados por **comunidad autónoma** y **periodo temporal**, a partir de los informes históricos disponibles en dicho portal.
#
# > Nota: Los precios analizados no representan precios de transacción final, sino precios de oferta publicados en el mercado inmobiliario, por lo que deben interpretarse como un indicador de la evolución del mercado y no como valores cerrados de compraventa o alquiler.

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Andalucia"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Andalucia")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Aragon"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Aragon")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Asturias"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Asturias")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Baleares"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Baleares")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Canarias"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Canarias")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Cantabria"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Cantabria")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Castilla y León"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Castilla y León")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Castilla-La Mancha"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Castilla-La Mancha")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Cataluña"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Cataluña")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Ceuta"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Ceuta")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Comunidad Valenciana"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Comunidad Valenciana")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Euskadi"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Euskadi")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Extremadura"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Extremadura")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Galicia"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Galicia")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "La Rioja"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/La Rioja")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Madrid"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Madrid")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Melilla"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Melilla")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Murcia"
if modify:
    df_andalucia.to_csv("../../data/raw/venta/Murcia")

# %%
df_andalucia = pd.read_clipboard()
df_andalucia["Comunidad Autonoma"] = "Navarra"
if modify:
    df_andalucia.to_csv("../../data/raw/alquiler/Navarra")

# %% [markdown]
# ## Función `select_df`
#
# La función `select_df` se utiliza para cargar datos inmobiliarios desde archivos **CSV** y devolverlos como un `DataFrame` de **pandas**.
# Los datos están organizados **únicamente** por tipo de operación (**Venta** o **Alquiler**) y por **Comunidad Autónoma**.

# %%
def select_df(tipo:str, ccaa:str):
    return pd.read_csv(f"../../data/raw/{tipo}/{ccaa}")
