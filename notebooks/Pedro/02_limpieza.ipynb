# %% [markdown]
# # Cuaderno de limpieza de Pedro Herrero Bas

# %%
import sys
from pathlib import Path

ROOT_DIR = Path().resolve().parents[1]
sys.path.append(str(ROOT_DIR))

# %%
import pandas as pd

from src.utils import filtrar_columna

# %%
df_pib = pd.read_csv('../../data/interim/datos_pedro.csv', sep='|', index_col=0)
df_pib.sample(20)
# Out:
#       año               com_aut          pib      pob    sui    nat   paro  \
# 421  2022               Balears   37.187.160  1.198,5   7.09   7.58  14.32
# 390  2020           Extremadura   19.497.343  1.062,5   7.05   6.97  21.53
# 373  2019                Madrid  243.889.359  6.661,4   5.10   8.34  12.22
# 305  2016                Aragón   34.542.128  1.316,2   9.45   8.30  16.29
# 253  2013       Castilla Y León   51.280.425  2.504,7   7.32   7.11  19.80
# 378  2019                 Ceuta    1.659.979     84,8   1.11   9.96  29.01
# 396  2020                 Rioja    8.186.915    319,1   8.75   7.33   9.96
# 108  2005                Murcia   24.272.350  1.335,3  10.17  12.98    NaN
# 224  2011            País Vasco   63.907.269  2.184,0   5.50   9.69  10.69
# 268  2014              Asturias   20.636.251  1.053,5  12.16   6.26  24.13
# 83   2004  Castilla - La Mancha   30.276.086  1.849,7   8.32  10.01    NaN
# ...

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 474
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   año      475 non-null    int64
#  1   com_aut  475 non-null    object
#  2   pib      475 non-null    object
#  3   pob      475 non-null    object
#  4   sui      456 non-null    float64
#  5   nat      456 non-null    float64
#  6   paro     342 non-null    float64
#  7   ing      304 non-null    float64
#  8   pobr     190 non-null    float64
#  9   fum      171 non-null    float64
#  10  alc      133 non-null    float64
#  11  obes     171 non-null    float64
#  12  fyv      133 non-null    float64
#  13  crim     270 non-null    float64
#  14  homi     270 non-null    float64
#  15  sati     114 non-null    object
# dtypes: float64(11), int64(1), object(4)
# memory usage: 63.1+ KB

# %% [markdown]
# *Existen datos como PIB, población y satisfacción que me indica como objetos, voy a pasarlos a tipo, int y float, como deberían ser.*

# %%
df_pib.pib = df_pib.pib.str.replace('.', '').astype(int)
df_pib.pob = df_pib.pob.str.replace('.', '').str.replace(',', '.').astype(float)
df_pib.sati = df_pib.sati.str.replace(',', '.').astype(float)

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 474
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   año      475 non-null    int64
#  1   com_aut  475 non-null    object
#  2   pib      475 non-null    int64
#  3   pob      475 non-null    float64
#  4   sui      456 non-null    float64
#  5   nat      456 non-null    float64
#  6   paro     342 non-null    float64
#  7   ing      304 non-null    float64
#  8   pobr     190 non-null    float64
#  9   fum      171 non-null    float64
#  10  alc      133 non-null    float64
#  11  obes     171 non-null    float64
#  12  fyv      133 non-null    float64
#  13  crim     270 non-null    float64
#  14  homi     270 non-null    float64
#  15  sati     114 non-null    float64
# dtypes: float64(13), int64(2), object(1)
# memory usage: 63.1+ KB

# %%
df_x_com = filtrar_columna(df_pib, 'com_aut')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_x_com[0]
# Out:
#             año        pib     pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Andalucía  2000   86760722  7301.8    NaN  11.08    NaN      NaN   NaN    NaN
# Andalucía  2001   93964317  7341.5  11.17  11.06    NaN      NaN   NaN    NaN
# Andalucía  2002  101269401  7437.2  10.36  11.01    NaN      NaN   NaN  31.84
# Andalucía  2003  110093641  7544.2  10.35  11.42    NaN      NaN   NaN  30.39
# Andalucía  2004  119026615  7649.0  11.01  11.64    NaN      NaN   NaN  28.82
# Andalucía  2005  129255761  7803.4  10.18  11.76    NaN      NaN   NaN  26.65
# Andalucía  2006  139373481  7923.9  10.05  12.03    NaN      NaN   NaN  27.09
# Andalucía  2007  149010277  8052.8  10.18  11.93  12.62      NaN   NaN  24.37
# Andalucía  2008  152247439  8168.6   9.90  12.28  12.76      NaN   NaN  22.67
# Andalucía  2009  145802256  8244.5  10.87  11.48  17.73   9437.0   NaN  20.93
# Andalucía  2010  145853901  8302.9   9.89  11.10  25.24   9882.0   NaN  18.23
# ...

# %%
df_x_com[1]
# Out:
#           año       pib     pob   sui    nat   paro      ing  pobr    fum  \
# com_aut
# Aragón   2000  20431675  1200.8   NaN   8.29    NaN      NaN   NaN    NaN
# Aragón   2001  21935008  1203.2  7.94   8.62    NaN      NaN   NaN    NaN
# Aragón   2002  23732938  1217.6  7.02   8.51    NaN      NaN   NaN  29.44
# Aragón   2003  25329113  1231.4  9.33   8.93    NaN      NaN   NaN  28.85
# Aragón   2004  26975682  1244.5  6.77   9.21    NaN      NaN   NaN  26.34
# Aragón   2005  28982156  1263.8  8.28   9.20    NaN      NaN   NaN  24.77
# Aragón   2006  31411624  1283.0  7.64   9.57    NaN      NaN   NaN  25.87
# Aragón   2007  34148523  1309.4  6.09   9.82   5.52      NaN   NaN  23.93
# Aragón   2008  35439689  1336.4  7.31  10.23   5.30      NaN   NaN  24.13
# Aragón   2009  33814117  1344.5  7.21   9.72   7.29  11963.0   NaN  17.76
# Aragón   2010  34100336  1343.8  8.05   9.63  13.05  12904.0   NaN  15.48
# ...

# %%
df_x_com[2]
# Out:
#            año       pib     pob    sui   nat   paro      ing  pobr    fum  \
# com_aut
# Asturias  2000  14156303  1066.1    NaN  6.33    NaN      NaN   NaN    NaN
# Asturias  2001  15252724  1063.7  13.66  6.45    NaN      NaN   NaN    NaN
# Asturias  2002  16131558  1062.1  12.09  6.34    NaN      NaN   NaN  26.81
# Asturias  2003  17036426  1062.2  11.81  6.69    NaN      NaN   NaN  25.90
# Asturias  2004  18115298  1062.1  10.85  6.80    NaN      NaN   NaN  26.25
# Asturias  2005  19638043  1062.6  11.23  7.04    NaN      NaN   NaN  27.18
# Asturias  2006  21339027  1063.8  10.44  7.14    NaN      NaN   NaN  21.76
# Asturias  2007  22873639  1068.0  10.76  7.33   9.16      NaN   NaN  19.08
# Asturias  2008  23614274  1074.0  10.35  7.65   8.41      NaN   NaN  23.78
# Asturias  2009  22366414  1076.4   9.47  7.63   8.50  12412.0   NaN  19.24
# Asturias  2010  22590616  1076.2   9.77  7.21  13.42  13103.0   NaN  12.46
# ...

# %%
df_x_com[3]
# Out:
#           año       pib     pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Balears  2000  16505108   823.4    NaN  11.36    NaN      NaN   NaN    NaN
# Balears  2001  17867937   836.9   7.61  11.44    NaN      NaN   NaN    NaN
# Balears  2002  18912404   866.1   6.68  12.03    NaN      NaN   NaN  31.78
# Balears  2003  19867979   898.6   7.25  11.86    NaN      NaN   NaN  28.55
# Balears  2004  21228501   924.0   8.91  11.68    NaN      NaN   NaN  27.00
# Balears  2005  22962215   954.6   7.70  11.44    NaN      NaN   NaN  25.68
# Balears  2006  24935415   987.2   7.66  11.83    NaN      NaN   NaN  22.73
# Balears  2007  26749452  1025.2   7.43  11.62   6.44      NaN   NaN  23.03
# Balears  2008  27892127  1057.4   7.62  12.02   7.16      NaN   NaN  23.09
# Balears  2009  26770420  1078.1   8.16  11.17  10.16  11909.0   NaN  20.54
# Balears  2010  26797013  1087.6  10.00  11.00  17.92  12492.0   NaN  20.92
# ...

# %%
df_x_com[4]
# Out:
#            año       pib     pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Canarias  2000  24986123  1667.4    NaN  11.12    NaN      NaN   NaN    NaN
# Canarias  2001  27237439  1687.3   9.63  10.96    NaN      NaN   NaN    NaN
# Canarias  2002  29101803  1730.7   7.85  11.24    NaN      NaN   NaN  34.16
# Canarias  2003  31104840  1779.5   7.86  10.83    NaN      NaN   NaN  29.86
# Canarias  2004  32847221  1826.8   7.96  10.51    NaN      NaN   NaN  29.77
# Canarias  2005  35103749  1876.4   8.90  10.73    NaN      NaN   NaN  27.21
# Canarias  2006  37445827  1921.8   9.04  10.75    NaN      NaN   NaN  21.88
# Canarias  2007  39902031  1968.0   9.66  10.03  11.62      NaN   NaN  22.65
# Canarias  2008  41156055  2010.0   8.39  10.28  10.45      NaN   NaN  22.29
# Canarias  2009  39505370  2034.2   9.72   9.32  17.25   9416.0   NaN  20.69
# Canarias  2010  39738165  2053.1   8.60   8.92  26.01   9333.0   NaN  16.08
# ...

# %%
df_x_com[5]
# Out:
#             año       pib    pob   sui    nat   paro      ing  pobr    fum  \
# com_aut
# Cantabria  2000   7985491  533.6   NaN   8.16    NaN      NaN   NaN    NaN
# Cantabria  2001   8636331  534.6  5.01   8.02    NaN      NaN   NaN    NaN
# Cantabria  2002   9208673  538.6  4.76   8.47    NaN      NaN   NaN  32.78
# Cantabria  2003   9699398  544.9  5.35   8.94    NaN      NaN   NaN  28.62
# Cantabria  2004  10327246  551.0  6.28   9.18    NaN      NaN   NaN  31.34
# Cantabria  2005  11148678  558.0  4.37   9.44    NaN      NaN   NaN  27.63
# Cantabria  2006  11951944  564.2  5.39   9.27    NaN      NaN   NaN  23.92
# Cantabria  2007  12838674  572.6  4.32   9.39   6.46      NaN   NaN  21.40
# Cantabria  2008  13280853  581.2  2.69  10.13   5.96      NaN   NaN  22.88
# Cantabria  2009  12811684  586.8  3.98   9.58   7.16  11736.0   NaN  18.88
# Cantabria  2010  12882755  589.6  5.52   9.46  12.00  12697.0   NaN   9.94
# ...

# %%
df_x_com[6]
# Out:
#                   año       pib     pob   sui   nat   paro      ing  pobr  \
# com_aut
# Castilla Y León  2000  35666620  2467.7   NaN  7.26    NaN      NaN   NaN
# Castilla Y León  2001  37939899  2459.0  9.34  7.16    NaN      NaN   NaN
# Castilla Y León  2002  40240849  2458.0  7.97  7.36    NaN      NaN   NaN
# Castilla Y León  2003  42711006  2467.4  8.37  7.54    NaN      NaN   NaN
# Castilla Y León  2004  45368864  2475.3  9.09  7.64    NaN      NaN   NaN
# Castilla Y León  2005  48377632  2487.5  8.22  7.81    NaN      NaN   NaN
# Castilla Y León  2006  51563915  2502.6  6.97  7.90    NaN      NaN   NaN
# Castilla Y León  2007  55130537  2528.4  7.17  7.94   8.11      NaN   NaN
# Castilla Y León  2008  56295496  2546.4  7.94  8.37   7.13      NaN   NaN
# Castilla Y León  2009  54452146  2547.6  7.87  8.01   9.62  10852.0   NaN
# Castilla Y León  2010  54692531  2545.4  8.07  8.05  13.98  11590.0   NaN
# ...

# %%
df_x_com[7]
# Out:
#                        año       pib     pob   sui    nat   paro      ing  \
# com_aut
# Castilla - La Mancha  2000  22364758  1746.7   NaN   9.64    NaN      NaN
# Castilla - La Mancha  2001  24300480  1756.6  8.72   9.60    NaN      NaN
# Castilla - La Mancha  2002  26093633  1777.8  7.70   9.63    NaN      NaN
# Castilla - La Mancha  2003  28278754  1815.0  8.15   9.95    NaN      NaN
# Castilla - La Mancha  2004  30276086  1849.7  8.32  10.01    NaN      NaN
# Castilla - La Mancha  2005  33056938  1895.2  9.33  10.03    NaN      NaN
# Castilla - La Mancha  2006  35995174  1941.2  8.14  10.50    NaN      NaN
# Castilla - La Mancha  2007  39219857  2003.3  7.63  10.42   8.84      NaN
# Castilla - La Mancha  2008  40786424  2050.5  7.22  11.24   7.66      NaN
# Castilla - La Mancha  2009  39355657  2075.9  7.72  10.75  11.67   9530.0
# Castilla - La Mancha  2010  39436268  2090.6  7.69  10.52  18.88  10082.0
# ...

# %%
df_x_com[8]
# Out:
#            año        pib     pob   sui    nat   paro      ing  pobr    fum  \
# com_aut
# Cataluña  2000  122568772  6297.2   NaN  10.21    NaN      NaN   NaN    NaN
# Cataluña  2001  132816296  6330.9  7.66  10.31    NaN      NaN   NaN    NaN
# Cataluña  2002  141683092  6470.1  7.86  10.59    NaN      NaN   NaN  31.40
# Cataluña  2003  151640414  6639.1  7.93  11.03    NaN      NaN   NaN  28.38
# Cataluña  2004  162519729  6782.3  7.20  11.35    NaN      NaN   NaN  23.68
# Cataluña  2005  174583886  6944.2  7.33  11.49    NaN      NaN   NaN  24.18
# Cataluña  2006  189253240  7076.7  6.22  11.63    NaN      NaN   NaN  22.97
# Cataluña  2007  202742146  7232.3  5.49  11.62   6.49      NaN   NaN  23.65
# Cataluña  2008  208161832  7377.1  5.35  12.10   6.47      NaN   NaN  22.53
# Cataluña  2009  200745296  7447.3  5.84  11.44   8.89  13048.0   NaN  20.91
# Cataluña  2010  202602183  7477.3  5.94  11.28  16.22  13425.0   NaN  13.80
# ...

# %%
df_x_com[9]
# Out:
#                        año        pib     pob   sui    nat   paro      ing  \
# com_aut
# Comunitat Valenciana  2000   62769305  4118.0   NaN  10.09    NaN      NaN
# Comunitat Valenciana  2001   68573071  4150.8  9.15  10.27    NaN      NaN
# Comunitat Valenciana  2002   73368886  4254.3  8.52  10.39    NaN      NaN
# Comunitat Valenciana  2003   78234975  4381.6  7.30  10.80    NaN      NaN
# Comunitat Valenciana  2004   83792686  4496.1  8.68  10.89    NaN      NaN
# Comunitat Valenciana  2005   90325604  4625.3  8.29  10.95    NaN      NaN
# Comunitat Valenciana  2006   98090683  4736.7  8.73  11.14    NaN      NaN
# Comunitat Valenciana  2007  104836698  4867.7  7.90  11.19   8.33      NaN
# Comunitat Valenciana  2008  107950942  4959.6  8.30  11.51   8.74      NaN
# Comunitat Valenciana  2009  101989994  4984.4  7.65  10.51  11.99  10310.0
# Comunitat Valenciana  2010  101870024  4988.9  7.83  10.36  20.76  11018.0
# ...

# %%
df_x_com[10]
# Out:
#               año       pib     pob   sui   nat   paro      ing  pobr    fum  \
# com_aut
# Extremadura  2000  11111196  1059.2   NaN  9.57    NaN      NaN   NaN    NaN
# Extremadura  2001  11906392  1058.4  7.65  9.35    NaN      NaN   NaN    NaN
# Extremadura  2002  12696756  1058.0  6.69  9.24    NaN      NaN   NaN  30.16
# Extremadura  2003  13574328  1062.4  9.08  9.38    NaN      NaN   NaN  28.75
# Extremadura  2004  14509199  1066.2  6.78  9.28    NaN      NaN   NaN  24.97
# Extremadura  2005  15776610  1072.0  8.83  9.32    NaN      NaN   NaN  26.28
# Extremadura  2006  16826962  1077.9  8.98  9.39    NaN      NaN   NaN  24.69
# Extremadura  2007  18136908  1085.8  6.66  9.19  13.31      NaN   NaN  25.61
# Extremadura  2008  18842360  1091.5  7.26  9.84  12.98      NaN   NaN  23.90
# Extremadura  2009  18370208  1097.1  7.19  9.40  15.35   8407.0   NaN  25.32
# Extremadura  2010  18652452  1100.4  6.87  9.20  20.63   9481.0   NaN  21.48
# ...

# %%
df_x_com[11]
# Out:
#           año       pib     pob    sui   nat   paro      ing  pobr    fum  \
# com_aut
# Galicia  2000  33439492  2699.0    NaN  7.22    NaN      NaN   NaN    NaN
# Galicia  2001  36029481  2696.0  10.59  7.18    NaN      NaN   NaN    NaN
# Galicia  2002  38440880  2699.5   9.47  7.16    NaN      NaN   NaN  26.42
# Galicia  2003  41139764  2707.3  10.05  7.54    NaN      NaN   NaN  22.97
# Galicia  2004  44249719  2714.1  11.91  7.60    NaN      NaN   NaN  22.41
# Galicia  2005  47955337  2724.0  10.57  7.74    NaN      NaN   NaN  22.24
# Galicia  2006  51960207  2733.4  11.47  7.83    NaN      NaN   NaN  20.28
# Galicia  2007  56005680  2747.1  10.29  7.92   8.35      NaN   NaN  19.14
# Galicia  2008  58253982  2760.0  10.33  8.40   7.57      NaN   NaN  17.83
# Galicia  2009  56253055  2769.1   9.95  8.14   8.64   9764.0   NaN  17.71
# Galicia  2010  56787248  2771.8  11.37  7.95  12.44  10307.0   NaN  14.91
# ...

# %%
df_x_com[12]
# Out:
#           año        pib     pob   sui    nat   paro      ing  pobr    fum  \
# com_aut
# Madrid   2000  113369166  5353.4   NaN  10.83    NaN      NaN   NaN    NaN
# Madrid   2001  123638301  5405.0  4.34  11.16    NaN      NaN   NaN    NaN
# Madrid   2002  132944643  5561.6  4.96  11.36    NaN      NaN   NaN  36.00
# Madrid   2003  142555275  5708.4  5.01  11.75    NaN      NaN   NaN  28.19
# Madrid   2004  153296904  5808.0  5.06  11.88    NaN      NaN   NaN  26.54
# Madrid   2005  165661958  5912.3  5.42  11.73    NaN      NaN   NaN  25.06
# Madrid   2006  180932461  6003.9  4.51  11.98    NaN      NaN   NaN  20.94
# Madrid   2007  194151492  6152.8  3.71  12.16   6.30      NaN   NaN  23.21
# Madrid   2008  201865569  6283.7  2.59  12.54   6.24      NaN   NaN  19.00
# Madrid   2009  199290149  6354.1  2.95  11.95   8.61  13089.0   NaN  17.74
# Madrid   2010  198289849  6384.4  2.51  11.57  13.86  14100.0   NaN  13.30
# ...

# %%
df_x_com[13]
# Out:
#           año       pib     pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Murcia   2000  16088710  1176.1    NaN  12.25    NaN      NaN   NaN    NaN
# Murcia   2001  17524452  1191.8  11.02  12.66    NaN      NaN   NaN    NaN
# Murcia   2002  19015733  1224.4   8.65  12.65    NaN      NaN   NaN  35.33
# Murcia   2003  20644875  1260.7   8.97  13.04    NaN      NaN   NaN  28.60
# Murcia   2004  22159238  1291.9   8.53  12.91    NaN      NaN   NaN  29.82
# Murcia   2005  24272350  1335.3  10.17  12.98    NaN      NaN   NaN  26.68
# Murcia   2006  26355824  1367.4   8.73  13.23    NaN      NaN   NaN  25.01
# Murcia   2007  28418142  1404.9   9.84  13.24   7.88      NaN   NaN  25.56
# Murcia   2008  29541076  1431.5   7.58  13.54   7.54      NaN   NaN  23.25
# Murcia   2009  28076274  1448.5   8.73  12.82  12.44   9751.0   NaN  23.65
# Murcia   2010  28372216  1456.5   7.30  12.38  20.32   9859.0   NaN  19.68
# ...

# %%
df_x_com[14]
# Out:
#           año       pib    pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Navarra  2000  11309008  550.0    NaN   9.58    NaN      NaN   NaN    NaN
# Navarra  2001  12052307  554.2   8.63  10.31    NaN      NaN   NaN    NaN
# Navarra  2002  12847752  562.5   7.69  10.31    NaN      NaN   NaN  30.33
# Navarra  2003  13652158  572.5   9.68  10.80    NaN      NaN   NaN  27.24
# Navarra  2004  14550257  579.8   9.30  10.85    NaN      NaN   NaN  25.60
# Navarra  2005  15630219  587.9  10.08  10.46    NaN      NaN   NaN  28.26
# Navarra  2006  16772179  596.6   9.17  10.98    NaN      NaN   NaN  23.34
# Navarra  2007  17870475  609.8   6.55  10.82   5.37      NaN   NaN  23.17
# Navarra  2008  18620264  622.0  10.08  11.30   4.72      NaN   NaN  20.39
# Navarra  2009  18001876  630.1   8.67  10.86   6.83  13903.0   NaN  18.17
# Navarra  2010  18089072  635.0   9.29  10.67  10.84  14963.0   NaN  17.64
# ...

# %%
df_x_com[15]
# Out:
#              año       pib     pob   sui   nat   paro      ing  pobr    fum  \
# com_aut
# País Vasco  2000  40734167  2083.3   NaN  8.35    NaN      NaN   NaN    NaN
# País Vasco  2001  43515328  2082.5  8.15  8.49    NaN      NaN   NaN    NaN
# País Vasco  2002  45891095  2087.4  7.09  8.69    NaN      NaN   NaN  31.28
# País Vasco  2003  48403686  2097.3  8.81  9.19    NaN      NaN   NaN  26.69
# País Vasco  2004  51495040  2107.8  7.51  9.29    NaN      NaN   NaN  21.53
# País Vasco  2005  55364217  2121.0  7.82  9.29    NaN      NaN   NaN  27.24
# País Vasco  2006  59871764  2134.1  7.52  9.38    NaN      NaN   NaN  23.31
# País Vasco  2007  63889516  2151.1  6.69  9.57   7.16      NaN   NaN  22.75
# País Vasco  2008  66382420  2166.8  7.82  9.83   6.22      NaN   NaN  19.80
# País Vasco  2009  63601702  2177.0  7.52  9.60   6.63  14539.0   NaN  16.09
# País Vasco  2010  64424609  2181.1  7.27  9.71  11.34  15435.0   NaN  15.61
# ...

# %%
df_x_com[16]
# Out:
#           año       pib    pob    sui    nat   paro      ing  pobr    fum  \
# com_aut
# Rioja    2000   4931442  274.5    NaN   8.70    NaN      NaN   NaN    NaN
# Rioja    2001   5273021  276.2   6.75   8.81    NaN      NaN   NaN    NaN
# Rioja    2002   5566913  281.3  12.30   9.16    NaN      NaN   NaN  29.94
# Rioja    2003   6021536  287.7  12.37   9.98    NaN      NaN   NaN  25.20
# Rioja    2004   6383746  294.3   9.47   9.99    NaN      NaN   NaN  26.92
# Rioja    2005   6868905  300.6   9.39  10.11    NaN      NaN   NaN  29.43
# Rioja    2006   7427020  304.9   8.67  10.07    NaN      NaN   NaN  24.43
# Rioja    2007   7961817  312.4   9.02  10.47   6.11      NaN   NaN  21.76
# Rioja    2008   8264894  318.4   6.21  11.05   5.77      NaN   NaN  20.09
# Rioja    2009   7911873  319.8   8.97  10.41   7.90  11577.0   NaN  18.74
# Rioja    2010   8008552  319.9   8.43  10.55  12.64  12213.0   NaN  16.61
# ...

# %%
df_x_com[17]
# Out:
#           año      pib   pob    sui    nat   paro      ing  pobr    fum   alc  \
# com_aut
# Ceuta    2000   948660  71.0    NaN  13.97    NaN      NaN   NaN    NaN   NaN
# Ceuta    2001   985771  71.4   4.35  13.72    NaN      NaN   NaN    NaN   NaN
# Ceuta    2002  1040077  70.8   3.04  14.44    NaN      NaN   NaN  32.07   NaN
# Ceuta    2003  1109612  71.2   6.29  14.26    NaN      NaN   NaN  26.80   NaN
# Ceuta    2004  1170783  71.6   6.02  14.82    NaN      NaN   NaN  26.72   NaN
# Ceuta    2005  1236986  72.2   6.11  14.75    NaN      NaN   NaN  24.77   NaN
# Ceuta    2006  1327102  73.3   4.38  14.20    NaN      NaN   NaN  18.66   NaN
# Ceuta    2007  1420486  74.6   2.05  15.24  21.49      NaN   NaN  22.83  4.54
# Ceuta    2008  1483989  75.8   2.64  15.37  20.99      NaN   NaN  24.25  0.28
# Ceuta    2009  1484372  77.8   2.45  14.81  17.43   8537.0   NaN  20.09  2.00
# Ceuta    2010  1494058  80.6  10.79  14.79  18.55   9367.0   NaN   9.89  1.38
# ...

# %%
df_x_com[18]
# Out:
#           año      pib   pob    sui    nat   paro      ing  pobr    fum   alc  \
# com_aut
# Melilla  2000   870994  65.2    NaN  16.85    NaN      NaN   NaN    NaN   NaN
# Melilla  2001   906601  66.1   5.09  17.10    NaN      NaN   NaN    NaN   NaN
# Melilla  2002   947808  65.5   4.59  16.02    NaN      NaN   NaN  32.07   NaN
# Melilla  2003  1011565  65.0  10.33  17.04    NaN      NaN   NaN  26.80   NaN
# Melilla  2004  1076478  64.7   2.61  15.39    NaN      NaN   NaN  26.72   NaN
# Melilla  2005  1144982  66.4   3.35  15.25    NaN      NaN   NaN  18.80   NaN
# Melilla  2006  1227093  67.9   5.21  16.52    NaN      NaN   NaN  18.99   NaN
# Melilla  2007  1296125  70.1   0.00  15.87  13.59      NaN   NaN  15.34  4.54
# Melilla  2008  1357572  72.2   9.10  17.34  18.21      NaN   NaN  19.49  1.62
# Melilla  2009  1361870  74.5  10.48  17.09  19.99  12113.0   NaN  15.18  0.00
# Melilla  2010  1367400  77.4   8.20  17.55  23.49  12370.0   NaN  11.24  0.38
# ...

# %% [markdown]
# *Existen una gran cantidad de nulos distribuidos entre los distintos años de datos, habrá que restringir las variables que se pueden comparar entre ellas para no generar conclusiones erróneas.*

# %% [markdown]
# ## Resumen de datos

# %% [markdown]
# |Serie          |Tipo                |Interés| Descripción             |Notas|
# |---------------|--------------------|:-----:|-------------------------|-----|
# |Año            |Categórica numérica |3      |Año de los datos         |Índice numérico de los datos del dataset|
# |C. autónoma    |Categórica nominal  |3      |Comunidad autónoma       |Índice categórico de los datos del dataset|
# |PIB            |Numérica continua   |3      |Producto interior Bruto  |Valor en miles de euros|
# |Población      |Numérica continua   |3      |Población                |Valor en miles de personas|
# |Suicidios      |Numérica continua   |2      |Tasa de suicidios        |Defunciones por suicidios por 100.000 habitantes (**¡!<2023)**|
# |Natalidad      |Numérica continua   |2      |Tasa de natalidad        |Nacimientos por 1.000 habitantes|
# |Paro           |Numérica continua   |2      |Tasa de desempleo        |Parados entre activos por cien (**¡!CyM**)|
# |Ingresos       |Numérica continua   |3      |Tasa de ingresos         |Promedio de ingresos por persona adulta (**¡!CyM**)|
# |Pobreza        |Numérica continua   |2      |Tasa de riesgo de pobreza|Porcentaje de personas adultas en riesgo de pobreza (**¡!CyM**)|
# |Fumadores      |Numérica continua   |1      |Tasa de fumadores        |Porcentaje de personas adultas que se declaran fumadores|
# |Alcohol        |Numérica continua   |1      |Tasa de alcohol          |Porcentaje de personas adultas que declaran consumo de riesgo de alcohol|
# |Obesidad       |Numérica continua   |1      |Tasa de obesidad         |Porcentaje de personas adultas con IMC definido como obesidad|
# |Frutas/Verduras|Numérica continua   |1      |Consumo diario de F/V    |Porcentaje de personas adultas que declaran consumo diario de frutas y/o verduras|
# |Criminalidad   |Numérica continua   |2      |Tasa de criminalidad     |Número de infracciones penales por 1.000 habitantes|
# |Homicidios     |Numérica continua   |1      |Tasa de homicidios       |Número de homicidios y asesinatos (hechos conocidos) por 100.000 habitantes|
# |Satisfacción   |Numérica continua   |3      |Tasa de Satisfacción     |Porcentaje de personas adultas que valora su satisfacción general con la vida como notable o superior|

# %%
df_pib.to_csv('../../data/processed/datos_pedro.csv', sep='|')
